# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-total-female-births.csv")

# %%
df.head()
# Out:
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
df.tail()
# Out:
#            Date  Births
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50

# %%
df.shape
# Out:
# (365, 2)

# %%
df.dropna()
# Out:
#            Date  Births
# 0    1959-01-01      35
# 1    1959-01-02      32
# 2    1959-01-03      30
# 3    1959-01-04      31
# 4    1959-01-05      44
# ..          ...     ...
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50
#
# [365 rows x 2 columns]

# %%
Date=pd.date_range(start="1/1/1959", end="1/10/1959",freq="M")
Date
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='M')

# %%
df.plot(figsize=(20,8))
plt.title("Birth Rate per Day")
plt.xlabel("Date")
plt.ylabel("Birth")
plt.grid()

# %%
round(df.describe(),3)
# Out:
#         Births
# count  365.000
# mean    41.981
# std      7.348
# min     23.000
# 25%     37.000
# 50%     42.000
# 75%     46.000
# max     73.000
